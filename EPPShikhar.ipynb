# %%
# Load required modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB # Gaussian Naive Bays
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier #stochastic gradient descent
from sklearn.tree import DecisionTreeClassifier

# Garbage Collector
import gc

# %%
data = pd.read_csv('HenryHub.csv', parse_dates=[0], index_col=0, dayfirst=True)  # all data
data = data.iloc[:,:1]
data.head()
# Out:
#             HenryHub
# 2014-01-02      4.32
# 2014-01-03      4.39
# 2014-01-04      4.35
# 2014-01-05      4.35
# 2014-01-06      4.50

# %%
idx = pd.date_range('2014-01-02', '2017-10-24')

data.index = pd.DatetimeIndex(data.index)
data1 = data.reindex(idx, fill_value='NaN')
print(data1)
# Out:
#            HenryHub
# 2014-01-02     4.32
# 2014-01-03     4.39
# 2014-01-04     4.35
# 2014-01-05     4.35
# 2014-01-06      4.5
# 2014-01-07     4.58
# 2014-01-08     4.36
# 2014-01-09     4.15
# 2014-01-10     3.95
# 2014-01-11      NaN
# 2014-01-12      NaN
# 2014-01-13     4.19
# 2014-01-14     4.36
# 2014-01-15     4.45
# 2014-01-16     4.55
# 2014-01-17     4.39
# 2014-01-18      NaN
# 2014-01-19      NaN
# 2014-01-20      NaN
# 2014-01-21     4.61
# 2014-01-22     4.92
# 2014-01-23     5.64
# 2014-01-24     5.17
# 2014-01-25      NaN
# 2014-01-26      NaN
# 2014-01-27     5.66
# 2014-01-28     5.25
# 2014-01-29     5.23
# 2014-01-30     5.27
# 2014-01-31     5.04
# ...             ...
# 2017-09-25     2.96
# 2017-09-26     2.96
# 2017-09-27     2.98
# 2017-09-28     2.96
# 2017-09-29     2.94
# 2017-09-30      NaN
# 2017-10-01      NaN
# 2017-10-02     2.94
# 2017-10-03     2.73
# 2017-10-04      2.8
# 2017-10-05      2.8
# 2017-10-06     2.93
# 2017-10-07      NaN
# ...

# %%
data2 = data1.fillna(data1.mean(), inplace = True)
# Out:
#            HenryHub
# 2014-01-02     4.32
# 2014-01-03     4.39
# 2014-01-04     4.35
# 2014-01-05     4.35
# 2014-01-06      4.5
# 2014-01-07     4.58
# 2014-01-08     4.36
# 2014-01-09     4.15
# 2014-01-10     3.95
# 2014-01-11      NaN
# 2014-01-12      NaN
# 2014-01-13     4.19
# 2014-01-14     4.36
# 2014-01-15     4.45
# 2014-01-16     4.55
# 2014-01-17     4.39
# 2014-01-18      NaN
# 2014-01-19      NaN
# 2014-01-20      NaN
# 2014-01-21     4.61
# 2014-01-22     4.92
# 2014-01-23     5.64
# 2014-01-24     5.17
# 2014-01-25      NaN
# 2014-01-26      NaN
# 2014-01-27     5.66
# 2014-01-28     5.25
# 2014-01-29     5.23
# 2014-01-30     5.27
# 2014-01-31     5.04
# ...             ...
# 2017-09-25     2.96
# 2017-09-26     2.96
# 2017-09-27     2.98
# 2017-09-28     2.96
# 2017-09-29     2.94
# 2017-09-30      NaN
# 2017-10-01      NaN
# 2017-10-02     2.94
# 2017-10-03     2.73
# 2017-10-04      2.8
# 2017-10-05      2.8
# 2017-10-06     2.93
# 2017-10-07      NaN
# ...

# %%
import os
path_d = 'C:\\Users\\DELL User\\Desktop\\Berkeley\\290'
data1.to_csv(os.path.join(path_d, 'HenryHub.csv'))

# %%
data = pd.read_csv('NatGasFut1.csv', parse_dates=[0], index_col=0, dayfirst=True)  # all data
data = data.iloc[:,:1]
data.head()
# Out:
#             NatGasFut1
# 2014-01-02       4.321
# 2014-01-03       4.304
# 2014-01-06       4.306
# 2014-01-07       4.299
# 2014-01-08       4.216

# %%
idx = pd.date_range('2014-01-02', '2017-10-24')

data.index = pd.DatetimeIndex(data.index)
data1 = data.reindex(idx, fill_value='NaN')
print(data1)
# Out:
#            NatGasFut1
# 2014-01-02      4.321
# 2014-01-03      4.304
# 2014-01-04        NaN
# 2014-01-05        NaN
# 2014-01-06      4.306
# 2014-01-07      4.299
# 2014-01-08      4.216
# 2014-01-09      4.005
# 2014-01-10      4.053
# 2014-01-11        NaN
# 2014-01-12        NaN
# 2014-01-13      4.274
# 2014-01-14      4.369
# 2014-01-15      4.325
# 2014-01-16      4.382
# 2014-01-17      4.326
# 2014-01-18        NaN
# 2014-01-19        NaN
# 2014-01-20      4.326
# 2014-01-21      4.431
# 2014-01-22      4.689
# 2014-01-23       4.73
# 2014-01-24      5.182
# 2014-01-25        NaN
# 2014-01-26        NaN
# 2014-01-27      4.847
# 2014-01-28      5.033
# 2014-01-29      5.557
# 2014-01-30      5.011
# 2014-01-31      4.943
# ...               ...
# 2017-09-25      2.919
# 2017-09-26      2.918
# 2017-09-27      2.974
# 2017-09-28      3.017
# 2017-09-29      3.007
# 2017-09-30        NaN
# 2017-10-01        NaN
# 2017-10-02      2.916
# 2017-10-03      2.895
# ...

# %%
path_d = 'C:\\Users\\DELL User\\Desktop\\Berkeley\\290'
data1.to_csv(os.path.join(path_d, 'NatGasFut1.csv'))

# %%
data = pd.read_csv('California EIA data.csv', parse_dates=[0], index_col=0, dayfirst=True)  # all data
data.head()
# Out:
#         California : all fuels (utility-scale) thousand megawatthours  \
# Month
# Aug-17                                        21943.40919
# Jul-17                                        20980.32206
# Jun-17                                        18260.48619
# May-17                                        16878.55820
# Apr-17                                        15436.06640
#
#         California : coal thousand megawatthours  \
# Month
# Aug-17                                  24.78714
# Jul-17                                  23.12607
# Jun-17                                  26.82868
# May-17                                  14.41477
# Apr-17                                  19.33808
#
#         California : petroleum liquids thousand megawatthours  \
# Month
# Aug-17                                            3.31689
# Jul-17                                            3.44655
# Jun-17                                            3.31392
# ...

# %%
# Check correlation between features 
# (uncorrelated features are generally more powerful predictors)
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(data.astype(float).corr().round(2)\
            ,linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)

# %%
data = pd.read_csv('RetailSalesOFElectricityMonthly.csv', parse_dates=[0], index_col=0, dayfirst=True)  # all data
data.head()
# Out:
#         California : all sectors million kilowatthours  \
# Month
# Aug-17                                     26806.97165
# Jul-17                                     24342.39981
# Jun-17                                     22235.30692
# May-17                                     19838.08134
# Apr-17                                     17875.54180
#
#         California : residential million kilowatthours  \
# Month
# Aug-17                                     10492.74508
# Jul-17                                      9505.13584
# Jun-17                                      7581.84160
# May-17                                      6368.93969
# Apr-17                                      5656.12742
#
#         California : commercial million kilowatthours  \
# Month
# Aug-17                                    11327.78977
# Jul-17                                    10310.77062
# Jun-17                                    10191.93674
# ...

# %%
# Check correlation between features 
# (uncorrelated features are generally more powerful predictors)
colormap = plt.cm.viridis
plt.figure(figsize=(8,8))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(data.astype(float).corr().round(2)\
            ,linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)

# %%
data3 = pd.read_csv('NGmprice.csv')  # all data
#data3 = data3.iloc[:,1:]
data3.head()
# Out:
#       mprice
# 0  52.548000
# 1  48.619167
# 2  49.575455
# 3  49.170834
# 4  57.366669

# %%
# Out:
# mprice    52.118573
# dtype: float64

# %%
new =[]
for i in range(20,3551,20):
    new.append(data3.iloc[i-20:i].mean())
now = pd.DataFrame(new)

# %%
now.shape
# Out:
# (177, 1)

# %%
meandata = []
meandata1 = []
for j in range(0,2):
    for i in range(0,19):
        meandat = (data3.iloc[20*j:20*j + i,:])
        meandata.append(meandat)
    #meandata.mean()  
meandata
# Out:
# [Empty DataFrame
#  Columns: [mprice]
#  Index: [],    mprice
#  0  52.548,       mprice
#  0  52.548000
#  1  48.619167,       mprice
#  0  52.548000
#  1  48.619167
#  2  49.575455,       mprice
#  0  52.548000
#  1  48.619167
#  2  49.575455
#  3  49.170834,       mprice
#  0  52.548000
#  1  48.619167
#  2  49.575455
#  3  49.170834
#  4  57.366669,       mprice
#  0  52.548000
#  1  48.619167
#  2  49.575455
#  3  49.170834
#  4  57.366669
#  5  53.242001,       mprice
#  0  52.548000
#  1  48.619167
#  2  49.575455
#  3  49.170834
#  4  57.366669
#  5  53.242001
#  6  52.262726,       mprice
#  0  52.548000
#  1  48.619167
#  2  49.575455
#  3  49.170834
#  4  57.366669
#  5  53.242001
#  6  52.262726
#  7  50.912727,       mprice
#  0  52.548000
#  1  48.619167
#  2  49.575455
#  3  49.170834
#  4  57.366669
#  5  53.242001
#  6  52.262726
#  7  50.912727
#  8  56.312729,       mprice
#  0  52.548000
#  1  48.619167
#  2  49.575455
#  3  49.170834
#  4  57.366669
# ...

# %%
data3.iloc[0:0,:]
# Out:
# Empty DataFrame
# Columns: [mprice]
# Index: []

# %%
meandata
# Out:
# [Empty DataFrame
#  Columns: []
#  Index: [], Empty DataFrame
#  Columns: []
#  Index: [52.548], Empty DataFrame
#  Columns: []
#  Index: [52.548, 48.619167], Empty DataFrame
#  Columns: []
#  Index: [52.548, 48.619167, 49.575455], Empty DataFrame
#  Columns: []
#  Index: [52.548, 48.619167, 49.575455, 49.170834], Empty DataFrame
#  Columns: []
#  Index: [52.548, 48.619167, 49.575455, 49.170834, 57.366669], Empty DataFrame
#  Columns: []
#  Index: [52.548, 48.619167, 49.575455, 49.170834, 57.366669, 53.242001], Empty DataFrame
#  Columns: []
#  Index: [52.548, 48.619167, 49.575455, 49.170834, 57.366669, 53.242001, 52.262726], Empty DataFrame
#  Columns: []
#  Index: [52.548, 48.619167, 49.575455, 49.170834, 57.366669, 53.242001, 52.262726, 50.912727], Empty DataFrame
#  Columns: []
#  Index: [52.548, 48.619167, 49.575455, 49.170834, 57.366669, 53.242001, 52.262726, 50.912727, 56.312729], Empty DataFrame
#  Columns: []
# ...
