# %%
# use time series predict retail price directly

from pandas import Series
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
series = Series.from_csv('Average.retail.price.of.electricity.monthly.California...all.sectors.cents.per.kilowatthour.csv', header=0)
# split dataset
X = series.values
train, test = X[0:len(X)], X[len(X):]
# train autoregression
model = AR(train)
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+12*3, dynamic=False)

pyplot.plot(predictions, color='red')
pyplot.title('Average.retail.price.of.electricity.monthly.California...all.sectors.cents.per.kilowatthour in the next 3 years(from 2017-1 to 2020-8)')
pyplot.show()
import pandas as pd
stamps = pd.date_range('2017-08 ', periods=12*3+1, freq='MS')
df1 = pd.DataFrame(stamps,columns=['Time'])
df2 = pd.DataFrame(predictions,columns=['Average.retail.price.of.electricity.monthly.California...all.sectors.cents.per.kilowatthour'])
# Out:
# Lag: 14
# Coefficients: [-0.03821951  0.5815457   0.07861628  0.03190505 -0.01061763 -0.09989
#   0.20108226 -0.10290673  0.00249102 -0.03137411  0.05293429  0.16418292
#   0.55469149 -0.25106421 -0.16235088]
# C:\Users\kunya\Anaconda3\envs\data-x\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
#frames = [df1, df2]
#result = pd.concat(frames)
#result

# %%
# BioMass.Prod.Trill.BTU.

from pandas import Series
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
series = Series.from_csv('BioMass.Prod.Trill.BTU..csv', header=0)
# split dataset
X = series.values
train, test = X[0:len(X)], X[len(X):]
# train autoregression
model = AR(train)
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+12*3, dynamic=False)

pyplot.plot(predictions, color='red')
pyplot.title('BioMass.Prod.Trill.BTU. in the next 3 years(from 2017-1 to 2020-8)')
pyplot.show()
df3 = pd.DataFrame(predictions,columns=['BioMass.Prod.Trill.BTU.'])
# Out:
# Lag: 14
# Coefficients: [ 5.67497804  0.65097026  0.16914867  0.03856445  0.05291817  0.06694866
#  -0.04384594  0.02608935 -0.03929183 -0.07010603 -0.06586644 -0.04564795
#   0.8756188  -0.56228139 -0.0650014 ]

# %%
# Electricity.Imports..Billion.Kilowatthours.

from pandas import Series
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
series = Series.from_csv('Electricity.Imports..Billion.Kilowatthours..csv', header=0)
# split dataset
X = series.values
train, test = X[0:len(X)], X[len(X):]
# train autoregression
model = AR(train)
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+12*3, dynamic=False)

pyplot.plot(predictions, color='red')
pyplot.title('Electricity.Imports..Billion.Kilowatthours. in the next 3 years(from 2017-1 to 2020-8)')
pyplot.show()
df4 = pd.DataFrame(predictions,columns=['Electricity.Imports..Billion.Kilowatthours.'])
# Out:
# Lag: 14
# Coefficients: [ 0.19527273  0.69402511  0.03628104  0.00922743  0.12645181 -0.03496991
#  -0.03233473  0.04902121 -0.08116764 -0.10970216  0.06327714  0.13737221
#   0.44725213 -0.2259293  -0.11379098]

# %%
# Electricity.Net.Generation..Commercial.Sector..Billion.Kilowatthours.

from pandas import Series
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
series = Series.from_csv('Electricity.Net.Generation..Commercial.Sector..Billion.Kilowatthours..csv', header=0)
# split dataset
X = series.values
train, test = X[0:len(X)], X[len(X):]
# train autoregression
model = AR(train)
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+12*3, dynamic=False)

pyplot.plot(predictions, color='red')
pyplot.title('Electricity.Net.Generation..Commercial.Sector..Billion.Kilowatthours. in the next 3 years(from 2017-1 to 2020-8)')
pyplot.show()
df5 = pd.DataFrame(predictions,columns=['Electricity.Net.Generation..Commercial.Sector..Billion.Kilowatthours.'])
# Out:
# Lag: 14
# Coefficients: [ 0.01737752  0.63222238  0.15643278 -0.10523977  0.02654551  0.08135197
#  -0.00268916  0.00200455  0.01493417 -0.0608557   0.0713678   0.04801396
#   0.66126579 -0.43006339 -0.10911321]

# %%
# GDP

from pandas import Series
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
series = Series.from_csv('GDP.csv', header=0)
# split dataset
X = series.values
train, test = X[0:len(X)], X[len(X):]
# train autoregression
model = AR(train)
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+12*3, dynamic=False)

pyplot.plot(predictions, color='red')
pyplot.title('GDP in the next 3 years(from 2017-1 to 2020-8)')
pyplot.show()
df6 = pd.DataFrame(predictions,columns=['GDP'])
# Out:
# Lag: 14
# Coefficients: [  2.03993286e+01   3.65725260e-01   2.77176381e-01   2.07756709e-01
#    1.47284741e-01   9.80943993e-02   5.91663351e-02   3.16876396e-02
#    1.07010336e-02  -5.96356148e-03  -2.12565511e-02  -3.72911911e-02
#   -5.04175284e-02  -4.39322487e-02  -4.74953390e-02]

# %%
# GenCalifornia...other.renewables.thousand.megawatthours

from pandas import Series
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
series = Series.from_csv('GenCalifornia...other.renewables.thousand.megawatthours.csv', header=0)
# split dataset
X = series.values
train, test = X[0:len(X)], X[len(X):]
# train autoregression
model = AR(train)
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+12*3, dynamic=False)

pyplot.plot(predictions, color='red')
pyplot.title('GenCalifornia...other.renewables.thousand.megawatthours in the next 3 years(from 2017-1 to 2020-8)')
pyplot.show()
df7 = pd.DataFrame(predictions,columns=['GenCalifornia...other.renewables.thousand.megawatthours'])
# Out:
# Lag: 14
# Coefficients: [ -1.25865642e+02   5.32549042e-01   1.62782077e-01   2.95938425e-02
#   -2.01093939e-01   1.19628045e-01  -1.99663196e-01   1.44453333e-01
#   -1.04101031e-02   1.48093238e-01   4.35006143e-02   7.01726374e-05
#    4.85401392e-01  -1.31108213e-01  -4.30943015e-02]

# %%
# use time series predict retail price directly

from pandas import Series
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
series = Series.from_csv('GeoConsump.TrillBtu..csv', header=0)
# split dataset
X = series.values
train, test = X[0:len(X)], X[len(X):]
# train autoregression
model = AR(train)
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+12*3, dynamic=False)

pyplot.plot(predictions, color='red')
pyplot.title('GeoConsump.TrillBtu. in the next 3 years(from 2017-1 to 2020-8)')
pyplot.show()
df8 = pd.DataFrame(predictions,columns=['GeoConsump.TrillBtu.'])
# Out:
# Lag: 14
# Coefficients: [ 0.2388899   0.32105254  0.08447402  0.09182562  0.08374507  0.05236628
#   0.00304117  0.10028944  0.04386195  0.04562632  0.02158655 -0.09410283
#   0.62400084 -0.37712013 -0.00760674]

# %%
# Natural.Gas.Consumed.by.the.Electric.Power.Sector..Billion.Cubic.Feet.

from pandas import Series
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
series = Series.from_csv('Natural.Gas.Consumed.by.the.Electric.Power.Sector..Billion.Cubic.Feet..csv', header=0)
# split dataset
X = series.values
train, test = X[0:len(X)], X[len(X):]
# train autoregression
model = AR(train)
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+12*3, dynamic=False)

pyplot.plot(predictions, color='red')
pyplot.title('Natural.Gas.Consumed.by.the.Electric.Power.Sector..Billion.Cubic.Feet. in the next 3 years(from 2017-1 to 2020-8)')
pyplot.show()
df9 = pd.DataFrame(predictions,columns=['Natural.Gas.Consumed.by.the.Electric.Power.Sector..Billion.Cubic.Feet.'])
# Out:
# Lag: 14
# Coefficients: [  2.29371135e+01   7.94438958e-01  -4.67777680e-02   5.58565691e-03
#   -9.23562084e-04   6.53978433e-02  -1.17010053e-01   9.10700396e-02
#   -1.06815162e-02  -1.07864791e-01   9.92480535e-02   1.13195883e-01
#    6.19360317e-01  -4.26122141e-01  -1.10116312e-01]

# %%
# Natural.Gas.Consumed.by.the.Industrial.Sector..Lease.and.Plant.Fuel..Billion.Cubic.Feet.

from pandas import Series
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
series = Series.from_csv('Natural.Gas.Consumed.by.the.Industrial.Sector..Lease.and.Plant.Fuel..Billion.Cubic.Feet..csv', header=0)
# split dataset
X = series.values
train, test = X[0:len(X)], X[len(X):]
# train autoregression
model = AR(train)
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+12*3, dynamic=False)

pyplot.plot(predictions, color='red')
pyplot.title('Natural.Gas.Consumed.by.the.Industrial.Sector..Lease.and.Plant.Fuel..Billion.Cubic.Feet. in the next 3 years(from 2017-1 to 2020-8)')
pyplot.show()
df10 = pd.DataFrame(predictions,columns=['Natural.Gas.Consumed.by.the.Industrial.Sector..Lease.and.Plant.Fuel..Billion.Cubic.Feet.'])
# Out:
# Lag: 14
# Coefficients: [-0.16012608  0.6163757   0.04196233  0.0941696   0.05903194  0.05455231
#  -0.04133978  0.06525368  0.04369216 -0.04313655 -0.07390839 -0.16204426
#   0.73687015 -0.51974175  0.13584882]

# %%
# Natural.Gas.Consumed.by.the.Transportation.Sector..Pipelines.and.Distribution..Billion.Cubic.Feet.

from pandas import Series
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
series = Series.from_csv('Natural.Gas.Consumed.by.the.Transportation.Sector..Pipelines.and.Distribution..Billion.Cubic.Feet..csv', header=0)
# split dataset
X = series.values
train, test = X[0:len(X)], X[len(X):]
# train autoregression
model = AR(train)
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+12*3, dynamic=False)

pyplot.plot(predictions, color='red')
pyplot.title('Natural.Gas.Consumed.by.the.Transportation.Sector..Pipelines.and.Distribution..Billion.Cubic.Feet. in the next 3 years(from 2017-1 to 2020-8)')
pyplot.show()
df11 = pd.DataFrame(predictions,columns=['Natural.Gas.Consumed.by.the.Transportation.Sector..Pipelines.and.Distribution..Billion.Cubic.Feet.'])
# Out:
# Lag: 14
# Coefficients: [ 4.46149694  0.66104256  0.04326861 -0.04297454 -0.07285584  0.1126481
#  -0.11488913  0.11760861 -0.07918348 -0.04648702 -0.03116661  0.37240891
#   0.36333937 -0.30165736 -0.06051432]

# %%
# Solar.Consump.TrillionBTU.

from pandas import Series
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
series = Series.from_csv('Solar.Consump.TrillionBTU..csv', header=0)
# split dataset
X = series.values
train, test = X[0:len(X)], X[len(X):]
# train autoregression
model = AR(train)
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+12*3, dynamic=False)

pyplot.plot(predictions, color='red')
pyplot.title('Solar.Consump.TrillionBTU.in the next 3 years(from 2017-1 to 2020-8)')
pyplot.show()
df12 = pd.DataFrame(predictions,columns=['Solar.Consump.TrillionBTU.'])
# Out:
# Lag: 14
# Coefficients: [-0.42473139  0.59064485  0.22407093 -0.05108533 -0.30754563  0.43471214
#  -0.2599719   0.12382982 -0.074399   -0.05190298  0.26812989  0.08361346
#   0.43208353  0.22524297 -0.51947248]

# %%
# WindConsump.TrillBTU.

from pandas import Series
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
series = Series.from_csv('WindConsump.TrillBTU..csv', header=0)
# split dataset
X = series.values
train, test = X[0:len(X)], X[len(X):]
# train autoregression
model = AR(train)
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+12*3, dynamic=False)

pyplot.plot(predictions, color='red')
pyplot.title('WindConsump.TrillBTU.in the next 3 years(from 2017-1 to 2020-8)')
pyplot.show()
df13 = pd.DataFrame(predictions,columns=['WindConsump.TrillBTU.'])
# Out:
# Lag: 14
# Coefficients: [ 2.46750454  0.38772383  0.23690396  0.03068738 -0.17133606  0.15798928
#  -0.04063532  0.08119828 -0.14337755 -0.00865191  0.10241028  0.2951734
#   0.32340982  0.12428025 -0.34178523]

# %%
df1.to_csv('Predicted_data.csv')
