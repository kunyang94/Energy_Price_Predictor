# %%
# use time series predict retail price directly ***3 years

from pandas import Series
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
series = Series.from_csv('Average.retail.price.of.electricity.monthly.California...all.sectors.cents.per.kilowatthour.csv', header=0)
# split dataset
X = series.values
train, test = X[0:len(X)-12*3], X[len(X)-12*3:]
# train autoregression
model = AR(train)
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)
for i in range(len(predictions)):
    print('predicted=%f, expected=%f' % (predictions[i], test[i]))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot results
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()

# print the predicted data (the bule one is the real data, the red one is the predicted data)
predictions = model_fit.predict(start=len(train)-12*3, end=len(train)+len(test)-1+2*12, dynamic=False)
pyplot.plot(X[len(train)-12*3:])
pyplot.plot(predictions, color='red')
pyplot.title('Average.retail.price.of.electricity.monthly.California...all.sectors.cents.per.kilowatthour in the next 5  years(from 2017-1 to 2020-8)')
pyplot.show()
# Out:
# C:\Users\kunya\Anaconda3\envs\data-x\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Lag: 14
# Coefficients: [-0.06925843  0.62417522  0.04481464  0.01982984 -0.02458993  0.02896534
#  -0.03363928  0.08095022 -0.07569835  0.03176049 -0.02809795  0.29576012
#   0.33499937 -0.07588766 -0.21199173]
# predicted=16.698876, expected=17.250000
# predicted=16.086452, expected=17.300000
# predicted=15.367021, expected=15.360000
# predicted=14.276157, expected=15.160000
# predicted=14.089079, expected=14.460000
# predicted=14.078031, expected=14.550000
# predicted=14.193885, expected=14.300000
# predicted=13.466611, expected=14.220000
# predicted=13.219550, expected=12.640000
# predicted=14.530995, expected=14.760000
# predicted=16.291482, expected=16.120000
# predicted=17.084774, expected=17.310000
# predicted=16.963351, expected=17.190000
# predicted=16.362001, expected=17.360000
# predicted=15.494480, expected=15.620000
# predicted=14.713708, expected=15.030000
# predicted=14.410178, expected=14.410000
# predicted=14.484953, expected=14.740000
# predicted=14.354295, expected=14.530000
# predicted=13.910401, expected=14.340000
# predicted=13.914972, expected=12.670000
# predicted=14.993065, expected=14.940000
# predicted=16.436993, expected=16.240000
# predicted=17.233379, expected=16.930000
# predicted=17.184642, expected=17.150000
# predicted=16.586172, expected=16.680000
# predicted=15.756495, expected=14.180000
# predicted=15.066525, expected=14.990000
# predicted=14.802596, expected=14.880000
# predicted=14.799852, expected=15.120000
# predicted=14.650228, expected=15.300000
# predicted=14.362594, expected=15.390000
# predicted=14.512454, expected=13.120000
# predicted=15.441955, expected=15.460000
# predicted=16.661402, expected=17.550000
# predicted=17.405589, expected=17.530000
# Test MSE: 0.387

# %%
# use time series predict retail price directly ***5 years

from pandas import Series
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
series = Series.from_csv('Average.retail.price.of.electricity.monthly.California...all.sectors.cents.per.kilowatthour.csv', header=0)
# split dataset
X = series.values
train, test = X[0:len(X)-12*5], X[len(X)-12*5:]
# train autoregression
model = AR(train)
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)
for i in range(len(predictions)):
    print('predicted=%f, expected=%f' % (predictions[i], test[i]))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot results
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()

# print the predicted data (the bule one is the real data, the red one is the predicted data)
predictions = model_fit.predict(start=len(train)-12*3, end=len(train)+len(test)-1+2*12, dynamic=False)
pyplot.plot(X[len(train)-12*3:])
pyplot.plot(predictions, color='red')
pyplot.title('Average.retail.price.of.electricity.monthly.California...all.sectors.cents.per.kilowatthour in the next 5  years(from 2017-1 to 2020-8)')
pyplot.show()
# Out:
# Lag: 13
# Coefficients: [ 1.06677311  0.71667487 -0.04742529  0.00996292 -0.10742766  0.03398829
#   0.00385755  0.08223125 -0.11279282  0.00708117  0.02652485  0.26545579
#   0.28168885 -0.24237987]
# predicted=14.155613, expected=15.200000
# predicted=13.772605, expected=15.510000
# predicted=13.000370, expected=13.290000
# predicted=12.453956, expected=12.880000
# predicted=12.350204, expected=12.670000
# predicted=12.662587, expected=13.030000
# predicted=12.433089, expected=12.980000
# predicted=12.388950, expected=12.840000
# predicted=12.572015, expected=12.980000
# predicted=13.236034, expected=13.800000
# predicted=14.051372, expected=15.840000
# predicted=14.062169, expected=15.780000
# predicted=13.997140, expected=15.660000
# predicted=13.535948, expected=15.660000
# predicted=12.896270, expected=14.640000
# predicted=12.520574, expected=14.020000
# predicted=12.501255, expected=13.230000
# predicted=12.590726, expected=13.860000
# predicted=12.471216, expected=13.650000
# predicted=12.506580, expected=13.590000
# predicted=12.754968, expected=11.740000
# predicted=13.276752, expected=14.470000
# predicted=13.762938, expected=15.990000
# predicted=13.893771, expected=17.050000
# predicted=13.790281, expected=17.250000
# predicted=13.353298, expected=17.300000
# predicted=12.861169, expected=15.360000
# predicted=12.594699, expected=15.160000
# predicted=12.561493, expected=14.460000
# predicted=12.571345, expected=14.550000
# predicted=12.535183, expected=14.300000
# predicted=12.617562, expected=14.220000
# predicted=12.860496, expected=12.640000
# predicted=13.254513, expected=14.760000
# predicted=13.603257, expected=16.120000
# predicted=13.730677, expected=17.310000
# predicted=13.598696, expected=17.190000
# predicted=13.227750, expected=17.360000
# predicted=12.852891, expected=15.620000
# predicted=12.646297, expected=15.030000
# predicted=12.594644, expected=14.410000
# predicted=12.588909, expected=14.740000
# predicted=12.602014, expected=14.530000
# predicted=12.703340, expected=14.340000
# predicted=12.919954, expected=12.670000
# predicted=13.226729, expected=14.940000
# predicted=13.491247, expected=16.240000
# predicted=13.580857, expected=16.930000
# predicted=13.443232, expected=17.150000
# predicted=13.141651, expected=16.680000
# predicted=12.850698, expected=14.180000
# predicted=12.680934, expected=14.990000
# predicted=12.624775, expected=14.880000
# predicted=12.623499, expected=15.120000
# predicted=12.661462, expected=15.300000
# predicted=12.766808, expected=15.390000
# predicted=12.955904, expected=13.120000
# predicted=13.200002, expected=15.460000
# predicted=13.399699, expected=17.550000
# predicted=13.452158, expected=17.530000
# Test MSE: 4.972
